# %%
import numpy as np
data = np.load('../data/similarity_matrix.npy')
data
# Out:
# array([[1.0000001 , 0.94858533, 0.7097073 , ..., 0.41387063, 0.33473417,
#         0.32657686],
#        [0.94858533, 0.99999994, 0.769638  , ..., 0.3864525 , 0.31018868,
#         0.31322885],
#        [0.7097073 , 0.769638  , 1.0000005 , ..., 0.40119988, 0.37992945,
#         0.38051903],
#        ...,
#        [0.41387063, 0.3864525 , 0.40119988, ..., 1.        , 0.5409528 ,
#         0.36520016],
#        [0.33473417, 0.31018868, 0.37992945, ..., 0.5409528 , 0.9999997 ,
#         0.4507308 ],
#        [0.32657686, 0.31322885, 0.38051903, ..., 0.36520016, 0.4507308 ,
#         0.9999999 ]], shape=(2222, 2222), dtype=float32)
